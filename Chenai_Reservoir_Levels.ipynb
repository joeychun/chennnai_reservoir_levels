# %%
import pandas as pd
from pandas_datareader import data
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np

import os

df = pd.read_csv("~/Downloads/chennai_reservoir_levels.csv")
df.set_index("Date",inplace=True)

pn = new_df["POONDI"]
ch = new_df["CHOLAVARAM"]
rh = new_df["REDHILLS"]
cb = new_df["CHEMBARAMBAKKAM"]



plt.subplots_adjust(bottom=.25, left=.25)

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20,10), sharex=True, sharey=False)

fig.suptitle('Chenai Reservoir Levels', fontsize=25, fontweight='bold')
pn.plot(ax=axs[0,0], kind='line', alpha=0.75, color='red')
ch.plot(ax=axs[0,1], kind='line', alpha=0.75, color='blue')
rh.plot(ax=axs[1,0], kind='line', alpha=0.75, color='green')
cb.plot(ax=axs[1,1], kind='line', alpha=0.75, color='orange')



axs[1,0].set_xlabel('Date', fontsize=15, fontweight='light')
axs[1,1].set_xlabel('Date', fontsize=15, fontweight='light')
axs[0,0].set_ylabel('Million Cubic Ft.',fontsize=15, fontweight='light')
axs[1,0].set_ylabel('Million Cubic Ft.',fontsize=15, fontweight='light')
plt.rc('axes.spines', **{'right':False, 'top':False})

for x in range(2):
    for y in range(2):
        axs[x,y].legend()


plt.show()

# %%
df.describe()
# Out:
#             POONDI   CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# count  5647.000000  5647.000000  5647.000000      5647.000000
# mean   1133.272203   240.020572  1568.345573      1321.381645
# std    1026.009311   274.601731   890.363617       957.057834
# min       0.900000     0.000000     0.000000         0.000000
# 25%     213.000000    22.300000   849.000000       471.500000
# 50%     782.000000    92.000000  1630.000000      1225.000000
# 75%    2006.000000   460.000000  2236.000000      2083.000000
# max    3231.000000   896.000000  3300.000000      3396.000000

# %%
# x = new_df["Date"]

# pd = new_df["POONDI"]
# ch = new_df["CHOLAVARAM"]
# rh = new_df["REDHILLS"]
# cb = new_df["CHEMBARAMBAKKAM"]

# plt.close('all')

# """
# #print(dates.index.tolist())
# for idx in dates.index.tolist():
#     # XX-YY-ZZZZ
#     date = dates[idx]
#     dates[idx] = date[6:10] + "/" + date[0:2] + "/" + date[3:5]
# """

# # Three subplots sharing both x/y axes
# f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, sharex='col', sharey='row')
# ax1.plot(x, pd)
# ax1.set_index("Date",inplace=True)
# ax1.set_title('Sharing both axes')
# ax2.plot(x, ch)
# ax2.set_index("Date",inplace=True)
# ax3.plot(x, rh)
# ax3.set_index("Date",inplace=True)
# ax4.plot(x, cb)
# ax4.set_index("Date",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-c0a5e32536e0> in <module>
# ----> 1 x = new_df["Date"]
#       2
# ...

# %%
pd.Series.append?

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

plt.close('all')

f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
ax1.plot(x, y)
ax1.set_title('Sharing x per column, y per row')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
ax4.plot(x, 2 * y ** 2 - 1, color='r')

# %%
print('hi')
